# %%
import requests
import re
import os
import traceback
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
from urllib.parse import quote
from urllib.request import Request, urlopen

# %%
CITY_LIST = ["shanghai", "beijing"]
URL = "http://www.dianping.com"

# %%
class crawler(object):
    
    def __init__():
        refer_url = URL
        food_url_format = "{}/{}/ch10".format(URL)

    def getHtmlText(url):
        headers = {
                    "User-Agent": UserAgent(verify_ssl=False).random,
                    "Host":"www.dianping.com",
                    "Referer": self.refer_url
                   }
        try:
            r=requests.get(url,headers=headers)
            r.raise_for_status()
            self.refer_url = url
            if (r.encoding != "UTF-8"):
                r.encoding = r.apparent_encoding
            return r.text
        except:
            return ""
    
    def parseHtmlText(url): 
        html= self.getHtmlText(url)
        soup = BeautifulSoup(html, "html.parser")
        return soup
    
    def start(city_list):
        for c in city_list:
            food_url = self.food_url_format.format(c)
            soup = self.parseHtmlText(root_url)
            area_urls = [area.attrs["href"] for area in soup.find("div", id="bussi-nav").find_all('a')]
            for a in area_urls:
                sub_soup = self.parseHtmlText(a)

# %%
headers = {
            "User-Agent": UserAgent(verify_ssl=False).random,
            "Host":"www.dianping.com",
            "Referer":"http://www.dianping.com/shanghai"
           }

r=requests.get("http://www.dianping.com/shanghai/ch10",headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
for i in range(10):
    for c in CITY_LIST[:1]:
        root_url = "http://www.dianping.com/{}".format(c)
        food_url = "http://www.dianping.com/{}/ch10".format(c)
        html = getHtmlText(food_url, root_url) 
        soup = BeautifulSoup(html, "html.parser")
        print(soup)
# Out:
# <html>
# <head>
# <link href="//www.dpfile.com/app/pc-common/dp_favicon.a4af753914321c8e82e402e2b4be01d7.ico" rel="icon" type="image/x-icon"/>
# <link href="//www.dpfile.com/app/pc-common/dp_favicon.a4af753914321c8e82e402e2b4be01d7.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>【上海美食】推荐,美食排行/大全/攻略-大众点评网</title>
# <meta content="上海美食推荐,美食排行榜,上海美食,美食,美食排行" name="Keywords"/>
# <meta content="附近好吃的美食有哪些,大众点评为您找到245630家好吃的美食餐厅,找上海美食,就上大众点评" name="Description"/>
# <meta content="format=html5; url=https://m.dianping.com/shanghai/ch10" http-equiv="mobile-agent"/>
# <link href="https://m.dianping.com/shanghai/ch10" media="only screen and (max-width: 640px)" rel="alternate"/>
# <meta charset="utf-8">
# <script type="text/javascript">
#         window._DP_HeaderData = {
#             'cityId': '1',
#             'cityChName': '上海',
#             'cityEnName': 'shanghai',
#             'pageType': 'search',
#             'userId': '',
#             'userName': '',
# ...

# %%
root_url = "http://www.dianping.com/shanghai".format(c)
food_url = "http://www.dianping.com/shanghai/ch10".format(c)
html = getHtmlText(food_url, root_url) 
soup = BeautifulSoup(html, "html.parser")

# %%
[area.attrs["href"] for area in soup.find("div", id="bussi-nav").find_all('a')]
# Out:
# ['http://www.dianping.com/shanghai/ch10/r812',
#  'http://www.dianping.com/shanghai/ch10/r801',
#  'http://www.dianping.com/shanghai/ch10/r811',
#  'http://www.dianping.com/shanghai/ch10/r838',
#  'http://www.dianping.com/shanghai/ch10/r854',
#  'http://www.dianping.com/shanghai/ch10/r2528',
#  'http://www.dianping.com/shanghai/ch10/r836',
#  'http://www.dianping.com/shanghai/ch10/r842',
#  'http://www.dianping.com/shanghai/ch10/r865',
#  'http://www.dianping.com/shanghai/ch10/r841',
#  'http://www.dianping.com/shanghai/ch10/r861',
#  'http://www.dianping.com/shanghai/ch10/r872',
#  'http://www.dianping.com/shanghai/ch10/r803',
#  'http://www.dianping.com/shanghai/ch10/r840',
#  'http://www.dianping.com/shanghai/ch10/r835',
#  'http://www.dianping.com/shanghai/ch10/r860']

# %%
html = getHtmlText('http://www.dianping.com/shanghai/ch10/r812', 'http://www.dianping.com/shanghai/ch10')

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
soup.find("div", class="txt").find("div", class="tit").find("a")
# Out:
# <html>
# <head>
# <link href="//www.dpfile.com/app/pc-common/dp_favicon.a4af753914321c8e82e402e2b4be01d7.ico" rel="icon" type="image/x-icon"/>
# <link href="//www.dpfile.com/app/pc-common/dp_favicon.a4af753914321c8e82e402e2b4be01d7.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>【上海静安寺美食】推荐,静安寺美食排行/大全/攻略-大众点评网</title>
# <meta content="上海美食推荐,静安寺美食排行榜,上海美食,静安寺美食,美食排行" name="Keywords"/>
# <meta content="静安寺附近好吃的美食有哪些,大众点评为您找到1420家好吃的静安寺美食餐厅,找上海美食,就上大众点评" name="Description"/>
# <meta content="format=html5; url=https://m.dianping.com/shanghai/ch10/r812" http-equiv="mobile-agent"/>
# <link href="https://m.dianping.com/shanghai/ch10/r812" media="only screen and (max-width: 640px)" rel="alternate"/>
# <meta charset="utf-8">
# <script type="text/javascript">
#         window._DP_HeaderData = {
#             'cityId': '1',
#             'cityChName': '上海',
#             'cityEnName': 'shanghai',
#             'pageType': 'search',
#             'userId': '',
# ...

# %%
# for i in range(10):
headers = {
            "User-Agent": UserAgent(verify_ssl=False).random,
            "Host":"www.dianping.com",
            "Referer": "http://www.dianping.com/hangzhou"
           }
request = Request(url="http://www.dianping.com/hangzhou/ch10/r23913", method="GET", headers=headers)

r = urlopen(request)
